# %%
from bs4 import BeautifulSoup
import requests

r = requests.get("https://www.century21.com/real-estate/santa-clara-ca/LCCASANTACLARA/?")
c = r.content

soup = BeautifulSoup(c, "html.parser")

print(soup.prettify())

all = soup.select('div .infinite-item.property-card')

print(len(all))
# Out:
# <!DOCTYPE html>
# <html data-usagetrack-config='{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}' lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="4c07bdfa5bc2a138becfc315e369d957" name="p:domain_verify"/>
#   <meta content="e9raIhQP3NycLRaTINlODKxv0x6FvB8YT8axZ-o7dfU" name="google-site-verification">
#    <meta content="Santa Clara Real Estate | Find Houses &amp; Homes for Sale in Santa Clara, CA" name="title"/>
#    <meta content="Search Santa Clara real estate property listings to find homes for sale in Santa Clara, CA. Browse houses for sale in Santa Clara today!" name="description">
# ...

# %%
for item in all:
    print(item.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", ""))
    print(item.find_all("div", {"class":["property-address","property-city"]})[0].text)
    print(item.find_all("div", {"class":["property-address","property-city"]})[1].text)
    
    try:
        print(item.find("div", {"class": "col-wrap-mid"}).find("strong").text)
    
    except:
        print("no beds/baths data available")
    print(" ")
# Out:
# $2,399,999
#
#                124 Tyler Ave
#
#
#             Santa Clara CA 95050
#
# 5
#
# $1,399,000
#
#                2230 Crocker Way
#
#
#             Santa Clara CA 95051
#
# 4
#
# $749,000
#
#                480 N Winchester Blvd 8
#
#
#             Santa Clara CA 95050
#
# 2
#
# $1,498,000
#
#                3368 Soares Ct
#
#
#             Santa Clara CA 95051
#
# 4
#
# $1,098,000
#
#                3137 San Juan Avenue
#
#
#             Santa Clara CA 95051
#
# 3
#
# $1,098,000
#
#                3137 San Juan Ave
#
#
#             Santa Clara CA 95051
#
# 3
#
# $1,098,000
#
#                1881 Hillebrant Pl
#
#
#             Santa Clara CA 95050
#
# 3
#
# $1,650,000
#
#                4032-4034 Davis St
#
#
#             Santa Clara CA 95054
#
# no beds/baths data available
#
# $1,900,000
#
#                1295 Manchester Dr
#
#
#             Santa Clara CA 95050
#
# no beds/baths data available
#
# $1,680,000
#
#                1285 Manchester Dr
#
#
# ...
